# %% [markdown]
# ## Mean
# - Mean is an average
#     - mean can be calculated by :- sum of all data points/ no. of data points
# ## Median
# - Mid value in Dataset
# ## Mode
# - frequently occuring data point out of all point
# ## Standard Deviation
# - underrrot((xi-mean)^2/N)
#     - Here N = total no. of data point
#     - Xi-Mean = Mean
#     ![image.png](attachment:image.png)

# %% [markdown]
# ## Variance
# - it is completely same like standard deviation
#     -![image.png](attachment:image.png)
#
# ## Percentile
# - example if i got 92% tile, it mean i am better than 92% student participate in the exam
# - It means i am in top 8 % of the condidate
# - calcute the percentile - how many elements are before the point/ total no. of elements
# ## IQR (Interquartile range)
# - it is direcctly connected to percentile
# - it is Q3-Q1, Q3 is 74 percentile, Q1 is 25 percentile
# ## Skewness
# - require balance data for any data science measure
# - Prperties of normal distribution if :-
#     - Mean = Mode =  Median = 0
#     - SD(sigma)=1
#     - skewness= 0
#     - kurtios = 3
# - skewness is when data set is not symmtrical
# - left skewed data = mean < median < mode
# - right skewed data = mean > median > mode

# %% [markdown]
# ## Kurtosis
# - If we plot the data, what is peak/ sharpness of the data
# - kurt= 0, then it means mesokurt
# - kurt<0 ,then it is platykurtic
# - kurt>0
#
# ## correlation
# - assume you have two column, i..e emp_salary & emp_experience - it is +ve correlation
# -
